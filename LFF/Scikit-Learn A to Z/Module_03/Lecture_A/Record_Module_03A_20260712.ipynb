# %% [markdown]
# # <font color="#418FDE" size="6.5" uppercase>**Built-In Datasets**</font>

# %% [markdown]
# >Last update: 20260712.
#
# By the end of this Lecture, you will be able to:
# - Load common built-in datasets and identify their intended machine learning task.
# - Inspect Bunch objects to locate data, targets, feature names, descriptions, and metadata.
# - Select suitable built-in datasets for classification, regression, image, and text demonstrations.

# %% [markdown]
# ## **1. Toy Dataset Tasks**

# %% [markdown]
# ### **1.1. Dataset Task Types**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_01_01.jpg?v=1783830681" width="250">
#
#
#
# >* Identify whether tasks are classification or regression.
# >* Toy datasets are small, clean learning tools.
#
# >* Targets reveal classification, regression, or unsupervised tasks.
# >* Task type guides models and evaluation.
#
# >* Input formats shape dataset task understanding.
# >* Good toy datasets connect concepts to applications.

# %% [markdown]
# ### **1.2. Dataset Task Types**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_01_02.jpg?v=1783830686" width="250">
#
#
#
# >* Identify classification or regression when loading datasets.
# >* Toy datasets simplify recognizing categories versus values.
#
# >* Targets reveal classification or regression tasks.
# >* Avoid confusing labels with numeric predictions.
#
# >* Toy datasets mirror real task selection.
# >* Ask: classes or continuous values predicted?

# %% [markdown]
# ### **1.3. Dataset Task Types**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_01_03.jpg?v=1783830683" width="250">
#
#
#
# >* Identify datasets by prediction task first.
# >* Targets reveal classification or regression use.
#
# >* Target categories suggest classification tasks.
# >* Numeric targets indicate regression decisions.
#
# >* Toy datasets vary by input format.
# >* Choose examples matching task and data type.

# %% [markdown]
# ## **2. Inspecting Real Datasets**

# %% [markdown]
# ### **2.1. Exploring Bunch Contents**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_02_01.jpg?v=1783830688" width="250">
#
#
#
# >* Inspect dataset containers before modeling begins.
# >* Find data, targets, names, and descriptions.
#
# >* Datasets include inputs, targets, and context.
# >* Inspect contents to choose suitable tasks.
#
# >* Check data, targets, names, and metadata.
# >* Prevent mistakes by interpreting fields carefully.

# %% [markdown]
# ### **2.2. Bunch Object Fields**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_02_02.jpg?v=1783830691" width="250">
#
#
#
# >* Bunch organizes datasets into named parts.
# >* Separate features from targets to avoid mistakes.
#
# >* Data and target define learning structure.
# >* Names explain features and target categories.
#
# >* Descriptions explain dataset meaning and cautions.
# >* Metadata helps choose suitable teaching datasets.

# %% [markdown]
# ### **2.3. Dataset Metadata**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_02_03.jpg?v=1783830693" width="250">
#
#
#
# >* Metadata explains dataset meaning and source.
# >* It links numbers to real tasks.
#
# >* Metadata explains measurements, labels, and data types.
# >* It reveals dataset uses and limitations.
#
# >* Metadata reveals caveats, provenance, and dataset limits.
# >* Read metadata before trusting model conclusions.

# %% [markdown]
# ## **3. Large Built In Datasets**

# %% [markdown]
# ### **3.1. Dataset Selection Guide**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_03_01.jpg?v=1783830695" width="250">
#
#
#
# >* Match datasets to task and data type.
# >* Choose complexity that fits teaching time.
#
# >* Balance dataset size, clarity, and computing needs.
# >* Choose explainable datasets matching learner readiness.
#
# >* Match datasets to modality and teaching needs.
# >* Balance realism, clarity, and manageable complexity.

# %% [markdown]
# ### **3.2. Text Dataset Choices**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_03_02.jpg?v=1783830697" width="250">
#
#
#
# >* Match text datasets to teaching goals.
# >* Labeled news shows classification and text workflow.
#
# >* Discussion posts show realistic text complexity.
# >* Good datasets balance challenge with interpretability.
#
# >* Match dataset size to teaching purpose.
# >* Support supervised, exploratory, and real tasks.

# %% [markdown]
# ### **3.3. Text Dataset Choices**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_03/Lecture_A/image_03_03.jpg?v=1783830698" width="250">
#
#
#
# >* Choose labeled text matching the teaching task.
# >* Use varied, realistic documents with clear categories.
#
# >* Text datasets reveal realistic language challenges.
# >* They teach preprocessing, features, and evaluation.
#
# >* Text datasets connect lessons to real systems.
# >* Choose authentic, interpretable data showing bias challenges.

# %% [markdown]
# # <font color="#418FDE" size="6.5" uppercase>**Built-In Datasets**</font>

# %% [markdown]
# In this lecture, you learned to:
# - Load common built-in datasets and identify their intended machine learning task.
# - Inspect Bunch objects to locate data, targets, feature names, descriptions, and metadata.
# - Select suitable built-in datasets for classification, regression, image, and text demonstrations.
#
# In the next Lecture (Lecture B), we will go over 'Generated Data'
