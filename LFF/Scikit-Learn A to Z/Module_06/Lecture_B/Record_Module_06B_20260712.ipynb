# %% [markdown]
# # <font color="#418FDE" size="6.5" uppercase>**Feature Spaces**</font>

# %% [markdown]
# >Last update: 20260712.
#
# By the end of this Lecture, you will be able to:
# - Combine parallel transformations with FeatureUnion and make_union.
# - Process heterogeneous columns using ColumnTransformer and column selectors.
# - Inspect feature names, sparse thresholds, weights, and nested composite estimators.

# %% [markdown]
# ## **1. Parallel Feature Unions**

# %% [markdown]
# ### **1.1. FeatureUnion Basics**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_01_01.jpg?v=1783909207" width="250">
#
#
#
# >* Run multiple transformations on the same data
# >* Combine outputs into one richer feature space
#
# >* Independent branches process the same original data
# >* Combined features give models complementary signals
#
# >* Experiment with modular parallel feature representations
# >* Keep pipelines organized, tunable, and reusable

# %% [markdown]
# ### **1.2. make union shorthand**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_01_02.jpg?v=1783909209" width="250">
#
#
#
# >* Build parallel transformations without manual names
# >* Concatenate outputs into one feature space
#
# >* View data through multiple transformation lenses
# >* Concise unions support quick feature experiments
#
# >* Automatic names affect inspection and tuning
# >* Use explicit names for complex workflows

# %% [markdown]
# ### **1.3. Transformer Weights**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_01_03.jpg?v=1783909214" width="250">
#
#
#
# >* Control each transformer’s feature contribution
# >* Emphasize or reduce whole feature groups
#
# >* Balance different feature views by importance
# >* Prevent large feature blocks from dominating
#
# >* Tune weights using validation data
# >* Make feature importance assumptions explicit

# %% [markdown]
# ## **2. Column Processing**

# %% [markdown]
# ### **2.1. ColumnTransformer Basics**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_02_01.jpg?v=1783909239" width="250">
#
#
#
# >* Different columns need different preprocessing steps
# >* ColumnTransformer combines them into one pipeline
#
# >* Specify name, transformer, and target columns
# >* Combine transformed columns into one feature matrix
#
# >* Organized, explicit preprocessing for each column group
# >* Consistent transformations across training and future data

# %% [markdown]
# ### **2.2. Column Selectors**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_02_02.jpg?v=1783909234" width="250">
#
#
#
# >* Route different column types to suitable transformations
# >* Avoid mismatched preprocessing that distorts data meaning
#
# >* Select columns by name, position, or type
# >* Use patterns for maintainable preprocessing pipelines
#
# >* Separate data structure from transformations
# >* Design selectors carefully for robust preprocessing

# %% [markdown]
# ### **2.3. Remainder Handling**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_02_03.jpg?v=1783909229" width="250">
#
#
#
# >* Remainder controls unselected column handling
# >* Avoid accidental feature loss or inclusion
#
# >* Pass through already-ready numeric columns
# >* Inspect passthrough columns to avoid leakage
#
# >* Transform leftover columns with shared preprocessing
# >* Verify schema changes and model intent

# %% [markdown]
# ## **3. Composite Details**

# %% [markdown]
# ### **3.1. Sparse Output Control**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_03_01.jpg?v=1783909223" width="250">
#
#
#
# >* Sparse encodings save memory for mostly-zero features
# >* Combined outputs affect speed and scalability
#
# >* Threshold chooses sparse or dense output
# >* Match storage to combined feature density
#
# >* Sparse choices affect each nested pipeline stage
# >* Preserve compatibility, scalability, and memory efficiency

# %% [markdown]
# ### **3.2. Feature Name Inspection**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_03_02.jpg?v=1783909225" width="250">
#
#
#
# >* Trace transformed columns to original data
# >* Support model interpretation and diagnostics
#
# >* Check columns reach the right transformations
# >* Spot messy categories and preprocessing errors
#
# >* Trace features through nested preprocessing branches
# >* Support debugging, explanation, and team communication

# %% [markdown]
# ### **3.3. Nested Composite Estimators**

# %% [markdown]
# <img src="https://cdn.jsdelivr.net/gh/mhrafiei/contents@main/LFF/Scikit-Learn A to Z/Module_06/Lecture_B/image_03_03.jpg?v=1783909227" width="250">
#
#
#
# >* Nest workflows for different feature types
# >* Combine branches under one estimator interface
#
# >* Modular workflows for heterogeneous feature types
# >* Trace transformations and diagnose feature issues
#
# >* Inspect feature paths across nested workflows
# >* Tune components for reproducible production pipelines

# %% [markdown]
# # <font color="#418FDE" size="6.5" uppercase>**Feature Spaces**</font>

# %% [markdown]
# In this lecture, you learned to:
# - Combine parallel transformations with FeatureUnion and make_union.
# - Process heterogeneous columns using ColumnTransformer and column selectors.
# - Inspect feature names, sparse thresholds, weights, and nested composite estimators.
#
# In the next Module (Module 7), we will go over 'None'
